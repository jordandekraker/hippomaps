# %%
import numpy as np
import matplotlib.pyplot as plt
import nibabel as nib
import sys
sys.path.insert(1, '/host/cassio/export03/data/opt/hippunfold_toolbox/hippunfold_toolbox')
import utils
import plotting
import os
import glob
from brainspace.gradient import GradientMaps
from brainspace.datasets import load_conte69
from brainspace.plotting import plot_hemispheres

surf_lh, surf_rh = load_conte69()

# %%
micapipe_dir = '../sourcedata/Micapipe_PNI'
hippunfold_dir = '../hippunfold/PNI_v1.3.0_super/hippunfold'
tmp_dir = 'tmp_rsfMRI'

subs = ['PNC002', 'PNC003', 'PNC006', 'PNC007', 'PNC009', 'PNC010', 'PNC015','PNC016', 'PNC018','PNC019']
ses = '01'
hemis = ['L','R']
labels = ['hipp','dentate'] 
sigma = 3 #Gaussian smoothing kernal sigma (mm)
ind = [range(419), range(419,483)] # index of how many dentate and hipp vertices are

# %% [markdown]
# # 0. Map data to hippocmapal surface

# %%
# !mkdir -p {tmp_dir}
shp = [419,64]

for sub in subs:
    if not glob.glob(f'{hippunfold_dir}/sub-{sub}/surf/sub-{sub}_hemi-{hemis[-1]}_space-T1w_den-2mm_label-{labels[-1]}_rsfMRI_smooth-{sigma}mm.func.gii'):

        # convert affines
        cmd1a = f'c3d_affine_tool '\
            f'-itk {micapipe_dir}/sub-{sub}/ses-{ses}/xfm/sub-{sub}_ses-{ses}_from-me_task-rest_bold_to-nativepro_mode-image_desc-affine_0GenericAffine.mat '\
            f'-o {tmp_dir}/sub-{sub}_ses-{ses}_tmp0GenericAffine0.txt'
        # !{cmd1a}
        cmd1b = f'c3d_affine_tool '\
            f'-itk {micapipe_dir}/sub-{sub}/ses-{ses}/xfm/sub-{sub}_ses-{ses}_from-nativepro_func_to-me_task-rest_bold_mode-image_desc-SyN_0GenericAffine.mat '\
            f'-inv '\
            f'-o {tmp_dir}/sub-{sub}_ses-{ses}_tmp0GenericAffine1.txt'
        # !{cmd1b}

        for h,hemi in enumerate(hemis):
            for l,label in enumerate(labels):
                #apply affines
                cmd2a = f'wb_command -surface-apply-affine '\
                    f'{hippunfold_dir}/sub-{sub}/surf/sub-{sub}_hemi-{hemi}_space-T1w_den-0p5mm_label-{label}_midthickness.surf.gii '\
                    f'{tmp_dir}/sub-{sub}_ses-{ses}_tmp0GenericAffine0.txt '\
                    f'{tmp_dir}/sub-{sub}_ses-{ses}_{h}_{l}_aff0.surf.gii'

                # !{cmd2a}
                cmd2b = f'wb_command -surface-apply-affine '\
                    f'{tmp_dir}/sub-{sub}_ses-{ses}_{h}_{l}_aff0.surf.gii '\
                    f'{tmp_dir}/sub-{sub}_ses-{ses}_tmp0GenericAffine1.txt '\
                    f'{tmp_dir}/sub-{sub}_ses-{ses}_{h}_{l}_aff1.surf.gii'
                # !{cmd2b}

                # apply warp (Note this is actually the INVERSE warp)
                cmd3 = f'wb_command -surface-apply-warpfield '\
                    f'{tmp_dir}/sub-{sub}_ses-{ses}_{h}_{l}_aff1.surf.gii '\
                    f'{micapipe_dir}/sub-{sub}/ses-{ses}/xfm/sub-{sub}_ses-{ses}_from-nativepro_func_to-me_task-rest_bold_mode-image_desc-SyN_1Warp.nii.gz '\
                    f'{tmp_dir}/sub-{sub}_ses-{ses}_{h}_{l}_deform.surf.gii'
                # !{cmd3}


                # sample
                cmd4 = f'wb_command -volume-to-surface-mapping '\
                    f'{micapipe_dir}/sub-{sub}/ses-{ses}/func/desc-me_task-rest_bold/volumetric/sub-{sub}_ses-{ses}_space-func_desc-me_preproc.nii.gz '\
                    f'{tmp_dir}/sub-{sub}_ses-{ses}_{h}_{l}_deform.surf.gii '\
                    f'{tmp_dir}/sub-{sub}_ses-{ses}_{h}_{l}_rsfMRI.func.gii '\
                    f'-enclosing'
                # !{cmd4}

                # smooth
                cmd5 = f'wb_command -metric-smoothing '\
                    f'{hippunfold_dir}/sub-{sub}/surf/sub-{sub}_hemi-{hemi}_space-T1w_den-0p5mm_label-{label}_midthickness.surf.gii '\
                    f'{tmp_dir}/sub-{sub}_ses-{ses}_{h}_{l}_rsfMRI.func.gii '\
                    f'{sigma} '\
                    f'{tmp_dir}/sub-{sub}_ses-{ses}_{h}_{l}_rsfMRI_smooth.func.gii '
                # !{cmd5}

                # downsample
                func = nib.load(f'{tmp_dir}/sub-{sub}_ses-{ses}_{h}_{l}_rsfMRI_smooth.func.gii')
                out_array = np.ones((len(func.darrays),shp[l]))
                for k in range(len(func.darrays)):
                    data, f, v = utils.density_interp('0p5mm', '2mm',func.darrays[k].data, label,'nearest')
                    out_array[k,:] = data
                data_array = nib.gifti.GiftiDataArray(data=out_array)
                image = nib.gifti.GiftiImage()
                image.add_gifti_data_array(data_array)
                nib.save(image, f'{hippunfold_dir}/sub-{sub}/surf/sub-{sub}_hemi-{hemi}_space-T1w_den-2mm_label-{label}_rsfMRI_smooth-{sigma}mm.func.gii')
                
# !rm -r {tmp_dir}

# %% [markdown]
# # 1. Calcualte ReHo

# %%
#%%capture
# !mkdir -p {tmp_dir}

for sub in subs:
    if not glob.glob(f'{hippunfold_dir}/sub-{sub}/surf/sub-{sub}_hemi-R_space-T1w_den-2mm_label-hipp_ReHo.shape.gii'):
        # calcualte reho
        cmd4 = f'3dReHo -prefix {tmp_dir}/sub-{sub}_ses-{ses}_ReHo '\
            f'-inset {micapipe_dir}/sub-{sub}/ses-{ses}/func/desc-me_task-rest_bold/volumetric/sub-{sub}_ses-{ses}_space-func_desc-me_preproc.nii.gz'
        # !{cmd4}
        # convert to nifti
        cmd5 = f'3dAFNItoNIFTI -prefix {tmp_dir}/sub-{sub}_ses-{ses}_ReHo.nii.gz {tmp_dir}/sub-{sub}_ses-{ses}_ReHo+orig'
        # !{cmd5}

        # convert affines
        cmd1a = f'c3d_affine_tool '\
            f'-itk {micapipe_dir}/sub-{sub}/ses-{ses}/xfm/sub-{sub}_ses-{ses}_from-me_task-rest_bold_to-nativepro_mode-image_desc-affine_0GenericAffine.mat '\
            f'-o {tmp_dir}/sub-{sub}_ses-{ses}_tmp0GenericAffine0.txt'
        # !{cmd1a}
        cmd1b = f'c3d_affine_tool '\
            f'-itk {micapipe_dir}/sub-{sub}/ses-{ses}/xfm/sub-{sub}_ses-{ses}_from-nativepro_func_to-me_task-rest_bold_mode-image_desc-SyN_0GenericAffine.mat '\
            f'-inv '\
            f'-o {tmp_dir}/sub-{sub}_ses-{ses}_tmp0GenericAffine1.txt'
        # !{cmd1b}

        for h,hemi in enumerate(hemis):
            for l,label in enumerate(labels):
                #apply affines
                cmd2a = f'wb_command -surface-apply-affine '\
                    f'{hippunfold_dir}/sub-{sub}/surf/sub-{sub}_hemi-{hemi}_space-T1w_den-0p5mm_label-{label}_midthickness.surf.gii '\
                    f'{tmp_dir}/sub-{sub}_ses-{ses}_tmp0GenericAffine0.txt '\
                    f'{tmp_dir}/sub-{sub}_ses-{ses}_{h}_{l}_aff0.surf.gii'

                # !{cmd2a}
                cmd2b = f'wb_command -surface-apply-affine '\
                    f'{tmp_dir}/sub-{sub}_ses-{ses}_{h}_{l}_aff0.surf.gii '\
                    f'{tmp_dir}/sub-{sub}_ses-{ses}_tmp0GenericAffine1.txt '\
                    f'{tmp_dir}/sub-{sub}_ses-{ses}_{h}_{l}_aff1.surf.gii'
                # !{cmd2b}

                # apply warp (Note this is actually the INVERSE warp)
                cmd3 = f'wb_command -surface-apply-warpfield '\
                    f'{tmp_dir}/sub-{sub}_ses-{ses}_{h}_{l}_aff1.surf.gii '\
                    f'{micapipe_dir}/sub-{sub}/ses-{ses}/xfm/sub-{sub}_ses-{ses}_from-nativepro_func_to-me_task-rest_bold_mode-image_desc-SyN_1Warp.nii.gz '\
                    f'{tmp_dir}/sub-{sub}_ses-{ses}_{h}_{l}_deform.surf.gii'
                # !{cmd3}

                # sample
                cmd4 = f'wb_command -volume-to-surface-mapping '\
                    f'{tmp_dir}/sub-{sub}_ses-{ses}_ReHo.nii.gz '\
                    f'{tmp_dir}/sub-{sub}_ses-{ses}_{h}_{l}_deform.surf.gii '\
                    f'{tmp_dir}/sub-{sub}_ses-{ses}_{h}_{l}_deform_ReHo.shape.gii '\
                    f'-enclosing'
                # !{cmd4}
                
                # downsample
                func = nib.load(f'{tmp_dir}/sub-{sub}_ses-{ses}_{h}_{l}_deform_ReHo.shape.gii')
                out_array = np.ones((len(func.darrays),shp[l]))
                for k in range(len(func.darrays)):
                    data, f, v = utils.density_interp('0p5mm', '2mm',func.darrays[k].data, label,'nearest')
                    out_array[k,:] = data
                data_array = nib.gifti.GiftiDataArray(data=out_array)
                image = nib.gifti.GiftiImage()
                image.add_gifti_data_array(data_array)
                nib.save(image, f'{hippunfold_dir}/sub-{sub}/surf/sub-{sub}_hemi-{hemi}_space-T1w_den-2mm_label-{label}_ReHo.shape.gii')

# !rm -r {tmp_dir}

# %%
reho = np.ones((483,2,len(subs)))*np.nan
for s,sub in enumerate(subs):
    for h,hemi in enumerate(hemis):
        for l,label in enumerate(labels):
            reho[ind[l],h,s] = nib.load(f'{hippunfold_dir}/sub-{sub}/surf/sub-{sub}_hemi-{hemi}_space-T1w_den-2mm_label-{label}_ReHo.shape.gii').darrays[0].data

# %%
plotting.surfplot_canonical_foldunfold(np.nanmean(reho,axis=(1,2)), hemis=['L'], den='2mm', unfoldAPrescale=True,  share='row', color_bar='right', embed_nb=True)
# Out:
# /export03/data/opt/venv/lib/python3.8/site-packages/brainspace/plotting/base.py:287: UserWarning: Interactive mode requires 'panel'. Setting 'interactive=False'
#   warnings.warn("Interactive mode requires 'panel'. "

# %%
# save a copy of the 2D map
for l,label in enumerate(labels):    
    cdat = np.nanmean(reho,axis=(1,2))[ind[l]]
    data_array = nib.gifti.GiftiDataArray(data=cdat)
    image = nib.gifti.GiftiImage()
    image.add_gifti_data_array(data_array)
    nib.save(image, f'../maps/MRI-7T-rsfMRI-ReHo_average-20_hemi-mix_den-2mm_label-{label}.shape.gii')

# %% [markdown]
# # 2. Intrinsic Timescale of hippocampal timeseries data

# %%
cdata_hipp = np.ones((483,2,275,len(subs)))*np.nan
for s,sub in enumerate(subs):
    for h,hemi in enumerate(hemis):
        for l,label in enumerate(labels):
            cdata_hipp[ind[l],h,:,s] = nib.load(f'{hippunfold_dir}/sub-{sub}/surf/sub-{sub}_hemi-{hemi}_space-T1w_den-2mm_label-{label}_rsfMRI_smooth-{sigma}mm.func.gii').darrays[0].data.T

# %%
t = cdata_hipp[302,0,:,1]
m = np.mean(t)
var = np.var(t)
ndat = t - m
acf = np.correlate(ndat, ndat, 'full')[len(ndat)-1:] 
acf = acf / var / len(ndat)
plt.plot(acf)

# %%
def IntrinsicTimescale(data, TR=1, threshold=0):
    '''computes instrinsic timescale - the AUC of the autocorrelation up to the point 
    where the autocorrelation reaches threshold. 
    Input
      img: input ND data, time being the last dimension
    '''
    shp = data.shape
    i = data.reshape(-1, shp[-1])
    out = np.zeros(i.shape[0])
    for v in range(i.shape[0]):
        m = np.mean(i[v,:])
        var = np.var(i[v,:])
        ndat = i[v,:] - m
        acf = np.correlate(ndat, ndat, 'full')[len(ndat)-1:] 
        acf = acf / var / len(ndat)
        f = np.where(acf<=threshold)[0]
        if len(f)==0:
            out[v] = np.nan
        else:
            out[v] = f[0]
    out = np.reshape(out,shp[:-1])*TR
    return out

# %%
TR = nib.load(f'{micapipe_dir}/sub-{sub}/ses-{ses}/func/desc-me_task-rest_bold/volumetric/sub-{sub}_ses-{ses}_space-func_desc-me_preproc.nii.gz').header.get_zooms()[-1]
IntTS = np.ones((483,2,len(subs)))*np.nan
for s,sub in enumerate(subs):
    IntTS[:,:,s] = IntrinsicTimescale(cdata_hipp[:,:,:,s],TR, threshold=0)
plotting.surfplot_canonical_foldunfold(np.nanmean(IntTS,axis=(1,2)), hemis=['L'], den='2mm', unfoldAPrescale=True, share='row', color_bar='right', zoom=1.7, embed_nb=True)
# Out:
# /tmp/ipykernel_17757/2710468927.py:15: RuntimeWarning: invalid value encountered in true_divide
#   acf = acf / var / len(ndat)
# /export03/data/opt/venv/lib/python3.8/site-packages/brainspace/plotting/base.py:287: UserWarning: Interactive mode requires 'panel'. Setting 'interactive=False'
#   warnings.warn("Interactive mode requires 'panel'. "

# %%
plt.hist(IntTS.flatten());

# %%
# save a copy of the 2D map
for l,label in enumerate(labels):    
    cdat = np.nanmean(IntTS,axis=(1,2))[ind[l]]
    data_array = nib.gifti.GiftiDataArray(data=cdat)
    image = nib.gifti.GiftiImage()
    image.add_gifti_data_array(data_array)
    nib.save(image, f'../maps/MRI-7T-rsfMRI-IntTS_average-20_hemi-mix_den-2mm_label-{label}.shape.gii')

# %%
tSNR = np.mean(cdata_hipp,axis=2) / np.std(cdata_hipp,axis=2)
plotting.surfplot_canonical_foldunfold(np.nanmean(tSNR,axis=2), den='2mm', unfoldAPrescale=True, share='row', color_bar='right', zoom=1.7, embed_nb=True)
# Out:
# /tmp/ipykernel_17757/3135166756.py:1: RuntimeWarning: invalid value encountered in true_divide
#   tSNR = np.mean(cdata_hipp,axis=2) / np.std(cdata_hipp,axis=2)

# %% [markdown]
# # 3. rs functional connectivity (FC)

# %%
#run gradients for all subjects
FC = np.ones((483,200,2,len(subs)))*np.nan
parcL = nib.load('/data/mica1/01_programs/micapipe/parcellations/schaefer-400_conte69_lh.label.gii').darrays[0].data
parcR = nib.load('/data/mica1/01_programs/micapipe/parcellations/schaefer-400_conte69_rh.label.gii').darrays[0].data
parc = np.concatenate((parcL,parcR))

clipaftertime = 200 # in TRs. This is an approximation
for s,sub in enumerate(subs):
    neo_ts = nib.load(f'{micapipe_dir}/sub-{sub}/ses-{ses}/func/desc-me_task-rest_bold/surf/sub-{sub}_ses-{ses}_surf-fsLR-32k_desc-timeseries_clean.shape.gii').darrays[0].data
    neo_ts_parc = np.ones((neo_ts.shape[0],400))
    for i in range(400):
         neo_ts_parc[:,i] = np.nanmean(neo_ts[:,parc==(i+1)],axis=1)
    neo_tsL = neo_ts_parc[:,:200]   
    neo_tsR = neo_ts_parc[:,200:]
    for h,hemi in enumerate(hemis):
        ts_hipp = nib.load(f'{hippunfold_dir}/sub-{sub}/surf/sub-{sub}_hemi-{hemi}_space-T1w_den-2mm_label-hipp_rsfMRI_smooth-{sigma}mm.func.gii').darrays[0].data
        ts_dg = nib.load(f'{hippunfold_dir}/sub-{sub}/surf/sub-{sub}_hemi-{hemi}_space-T1w_den-2mm_label-dentate_rsfMRI_smooth-{sigma}mm.func.gii').darrays[0].data
        ts_both = np.concatenate((ts_hipp,ts_dg), axis=1)
        if hemi == 'L':
            FC[:,:,h,s] = np.corrcoef(ts_both.T,neo_tsL.T)[:483,483:]
        else:            
            FC[:,:,h,s] = np.corrcoef(ts_both.T,neo_tsR.T)[:483,483:]
# Out:
# /export03/data/opt/venv/lib/python3.8/site-packages/numpy/lib/function_base.py:2691: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /export03/data/opt/venv/lib/python3.8/site-packages/numpy/lib/function_base.py:2692: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]

# %%
plt.hist(FC.flatten(),bins=50);
plt.hist(np.nanmean(FC,axis=(2,3)).flatten(),bins=50);

# %%
plotting.surfplot_canonical_foldunfold(np.nanmean(FC,axis=(1,2,3)), hemis=['L'], den='2mm', unfoldAPrescale=True, share='row', color_bar='right', embed_nb=True)

# %%
# save a copy of the 2D map
for l,label in enumerate(labels):    
    cdat = np.nanmean(FC,axis=(1,2,3))[ind[l]]
    data_array = nib.gifti.GiftiDataArray(data=cdat)
    image = nib.gifti.GiftiImage()
    image.add_gifti_data_array(data_array)
    nib.save(image, f'../maps/MRI-7T-rsfMRI-avgFCneocort_average-20_hemi-mix_den-2mm_label-{label}.shape.gii')

# %%
mc = np.zeros([surf_lh.n_points + surf_rh.n_points])
for h,hemi in enumerate(hemis):
    for i in range(200):
        mc[parc==(i+(h*200))] = np.nanmean(FC[:,i,h,:],axis=(0,1))

plot_hemispheres(surf_lh, surf_rh, array_name=np.hsplit(mc,1), 
                 size=(1000, 200), color_bar=True, embed_nb=True)

# %% [markdown]
# # 4. Gradientts of differential FC

# %%
ngrads = 5
gm = GradientMaps(n_components=ngrads, kernel='normalized_angle', random_state=0, alignment='procrustes')
gm.fit(np.nanmean(FC,axis=(2,3)))
    
plotting.surfplot_canonical_foldunfold(gm.gradients_, hemis=['L'], den='2mm', unfoldAPrescale=True, share='row', color_bar='right', color_range='sym', embed_nb=True)

# %%
plt.plot(gm.lambdas_)

# %%
# save a copy of the 2D map
for l,label in enumerate(labels):    
    cdat = gm.gradients_[ind[l],:]
    data_array = nib.gifti.GiftiDataArray(data=cdat)
    image = nib.gifti.GiftiImage()
    image.add_gifti_data_array(data_array)
    nib.save(image, f'../maps/MRI-7T-rsfMRI-FCG1to5_average-20_hemi-mix_den-2mm_label-{label}.shape.gii')

# %%
# look only at FC to the rest of the neocortex for the top-bottom 10% of each gradient
nverts = 483
nvertsplit = int(nverts*.25)

diffval = np.zeros([surf_lh.n_points + surf_rh.n_points,ngrads])
botval = np.zeros(surf_lh.n_points + surf_rh.n_points)
topval = np.zeros(surf_lh.n_points + surf_rh.n_points)
for g in range(ngrads):
    bot = np.argpartition(gm.gradients_[:,g],nvertsplit)[:nvertsplit]
    top = np.argpartition(gm.gradients_[:,g],-nvertsplit)[-nvertsplit:]
    for i in range(200):
        botval[parc==(i+(h*200))] = np.nanmean(FC[bot,i,:,:],axis=(0,1,2))
        topval[parc==(i+(h*200))] = np.nanmean(FC[top,i,:,:],axis=(0,1,2))
    diffval[:,g] = topval-botval

plot_hemispheres(surf_lh, surf_rh, array_name=np.hsplit(diffval,ngrads), 
                 size=(1000, 200*ngrads), color_bar=True, embed_nb=True, color_range='sym')
# Out:
# /export03/data/opt/venv/lib/python3.8/site-packages/brainspace/plotting/base.py:287: UserWarning: Interactive mode requires 'panel'. Setting 'interactive=False'
#   warnings.warn("Interactive mode requires 'panel'. "
